# %% [markdown]
# # Домашнее задание
# ## Harry Potter and the Action Prediction Challenge from Natural Language
#
# *deadline*: 14 ноября 2022, 23:59
#
# В этом домашнем задании вы будете работать с корпусом Harry Potter and the Action Prediction Challenge. Корпус собран из фанфиков о Гарри Поттере и состоит из двух частей: 1) сырые тексты, 2) фрагменты текстов, описывающих ситуацию, в которой произнесено заклинание.
#
# Корпус описан в статье: https://arxiv.org/pdf/1905.11037.pdf
#
# David Vilares and Carlos Gómez-Rodríguez. Harry Potter and the Action Prediction Challenge from Natural Language. 2019 Annual Conference of the North American Chapter of the Association for Computational Linguistics. To appear.
#
# Код для сбора корпуса находится в репозитории: https://github.com/aghie/hpac . Корпус можно скачать по инструкции из этого репозитория, но для экономии времени авторы задания уже скачали и подготовили данные к работе.
#
# Ссылки на собранный корпус:
# * Сырые тексты:  https://www.dropbox.com/s/23xet9kvbqna1qs/hpac_raw.zip?dl=0
# * Токенизированные тексты в нижнем регистре: https://www.dropbox.com/s/gwfgmomdbetvdye/hpac_lower_tokenized.zip?dl=0
# * train-test-dev: https://www.dropbox.com/s/3vdz0mouvex8abd/hpac_splits.zip?dl=0
#
# Части 1, 2 задания должны быть выполнены на полных текстах (сырых или предобработанных -- на ваше усмотрение), Часть 3 – на разбиение на тестовое, отладочное и обучающее множества. Тестовое множество должно быть использовано исключительно для тестирования моделей, обучающее и отладочное – для выбора модели и параметров.
#
# В статье и репозитории вы найдете идеи, которые помогут вам выполнить домашнее задание. Их стоит воспринимать как руководство к действию, и не стоит их копировать и переиспользовать. Обученные модели использовать не нужно, код для их обучения можно использовать как подсказку.
#
# ## ПРАВИЛА
# 1. Домашнее задание выполняется в группе до 3-х человек.
# 2. Домашнее задание оформляется в виде отчета либо в .pdf файле, либо ipython-тетрадке.
# 3. Отчет должен содержать: нумерацию заданий и пунктов, которые вы выполнили, код решения, и понятное пошаговое описание того, что вы сделали. Отчет должен быть написан в академическом стиле, без излишнего использования сленга и с соблюдением норм русского языка.
# 4. Не стоит копировать фрагменты лекций, статей и Википедии в ваш отчет.
# 5. Отчеты, состоящие исключительно из кода, не будут проверены и будут автоматически оценены нулевой оценкой.
# 6. Плагиат и любое недобросоветсное цитирование приводит к обнуление оценки.
#
#
# ## Часть 1. [2 балла] Эксплоративный анализ
# 1. Найдите топ-1000 слов по частоте без учета стоп-слов.
# 2. Найдите топ-10 по частоте: имен, пар имя + фамилия, пар вида ''профессор'' + имя / фамилия.
#
# [бонус] Постройте тематическую модель по корпусу HPAC.
#
# [бонус] Найдите еще что-то интересное в корпусе (что-то специфичное для фанфиков или фентези-тематики)
#
# ## Часть 2. [2 балла] Модели представления слов
# Обучите модель представления слов (word2vec, GloVe, fastText или любую другую) на материале корпуса HPAC.
# 1. Продемонстрируйте, как работает поиск синонимов, ассоциаций, лишних слов в обученной модели.
# 2. Визуализируйте топ-1000 слов по частоте без учета стоп-слов (п. 1.1) с помощью TSNE или UMAP (https://umap-learn.readthedocs.io).
#
# ## Часть 3. [5 баллов] Классификация текстов
# Задача классификации формулируется так: данный фрагмент фанфика описывают какую-то ситуацию, которая предшествует произнесению заклинания. Требуется по тексту предсказать, какое именно заклинание будет произнесено. Таким образом, заклинание - это фактически метка класса. Основная мера качества – macro $F_1$.
# Обучите несколько классификаторов и сравните их между собой. Оцените качество классификаторов на частых и редких классах. Какие классы чаще всего оказываются перепутаны? Связаны ли ошибки со смыслом заклинаний?
#
# Используйте фрагменты из множества train для обучения, из множества dev для отладки, из множества test – для тестирования и получения итоговых результатов.
#
# 1. [1 балл] Используйте fastText в качестве baseline-классификатора.
# 2. [2 балла] Используйте сверточные  или реккурентные сети в качестве более продвинутого классификатора. Поэкспериментируйте с количеством и размерностью фильтров, используйте разные размеры окон, попробуйте использовать $k$-max pooling.
# 3. [2 балла] Попробуйте расширить обучающее множество за счет аугментации данных. Если вам понадобится словарь синонимов, можно использовать WordNet (ниже вы найдете примеры).
#
# [бонус] Используйте результат max pooling'а как эмбеддинг входного текста. Визуализируйте эмбеддинги 500-1000 предложений из обучающего множества и изучите свойства получившегося пространства.
#
# [бонус] Используйте ваш любимый классификатор и любые (честные) способы повышения качества классификации и получите macro $F_1$ больше 0.5.
#
# ## Часть 4. [1 балл] Итоги
# Напишите краткое резюме проделанной работы. Читали ли вы сами Гарри Поттера или фанфики о нем и помогло ли вам знание предметной области в выполнении домашнего задания?

# %%
# !wget  https://www.dropbox.com/s/gwfgmomdbetvdye/hpac_lower_tokenized.zip
# Out:
# --2022-11-12 13:01:49--  https://www.dropbox.com/s/gwfgmomdbetvdye/hpac_lower_tokenized.zip?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.71.18
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.71.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/dl/gwfgmomdbetvdye/hpac_lower_tokenized.zip [following]
# --2022-11-12 13:01:49--  https://www.dropbox.com/s/dl/gwfgmomdbetvdye/hpac_lower_tokenized.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 404 Not Found
# 2022-11-12 13:01:50 ERROR 404: Not Found.

# %%
# !ls
# Out:
# hpac_lower_tokenized.zip hw1.ipynb

# %% [markdown]
# ### Данные
# Сырые тексты

# %%
# !unzip hpac_lower_tokenized
# Out:
# Archive:  hpac_lower_tokenized.zip
#    creating: hpac_source/
#   inflating: hpac_source/4472122
#   inflating: hpac_source/5214134
#   inflating: hpac_source/5287826
#   inflating: hpac_source/11996224
#   inflating: hpac_source/7887747
#   inflating: hpac_source/12680061
#   inflating: hpac_source/10780513
#   inflating: hpac_source/4457057
#   inflating: hpac_source/2849042
#   inflating: hpac_source/9768115
#   inflating: hpac_source/11395708
#   inflating: hpac_source/1537670
#   inflating: hpac_source/6345187
#   inflating: hpac_source/4660916
#   inflating: hpac_source/7226630
#   inflating: hpac_source/4161825
#   inflating: hpac_source/3728593
#   inflating: hpac_source/10668016
#   inflating: hpac_source/5009948
#   inflating: hpac_source/9429952
#   inflating: hpac_source/6268917
#   inflating: hpac_source/4559279
#   inflating: hpac_source/3748476
#   inflating: hpac_source/10690435
#   inflating: hpac_source/9314839
#   inflating: hpac_source/9776813
#   inflating: hpac_source/7432959
#   inflating: hpac_source/12456412
#   inflating: hpac_source/8222782
#   inflating: hpac_source/8298928
#   inflating: hpac_source/9685162
#   inflating: hpac_source/4108243
#   inflating: hpac_source/4782327
#   inflating: hpac_source/7006990
#   inflating: hpac_source/5848576
#   inflating: hpac_source/4506919
#   inflating: hpac_source/11310929
#   inflating: hpac_source/11414554
#   inflating: hpac_source/3047887
#   inflating: hpac_source/11214433
#   inflating: hpac_source/6808703
#   inflating: hpac_source/9183610
#   inflating: hpac_source/6264382
#   inflating: hpac_source/4304715
#   inflating: hpac_source/11708772
#   inflating: hpac_source/12421918
#   inflating: hpac_source/1518469
#   inflating: hpac_source/1996036
#   inflating: hpac_source/10196949
#   inflating: hpac_source/3280788
#   inflating: hpac_source/3877876
#   inflating: hpac_source/5155719
#   inflating: hpac_source/12567485
#   inflating: hpac_source/11261838
#   inflating: hpac_source/12049606
#   inflating: hpac_source/4993300
#   inflating: hpac_source/3817993
#   inflating: hpac_source/1873822
#   inflating: hpac_source/8884888
#   inflating: hpac_source/11477006
#   inflating: hpac_source/12629684
#   inflating: hpac_source/12646729
#   inflating: hpac_source/8625569
#   inflating: hpac_source/8215564
#   inflating: hpac_source/5916814
#   inflating: hpac_source/4731864
#   inflating: hpac_source/8566077
#   inflating: hpac_source/6886192
#   inflating: hpac_source/6224452
#   inflating: hpac_source/7593659
#   inflating: hpac_source/12690697
#   inflating: hpac_source/2715910
#   inflating: hpac_source/6236197
#   inflating: hpac_source/4043499
#   inflating: hpac_source/5304482
#   inflating: hpac_source/1986062
#   inflating: hpac_source/5834804
#   inflating: hpac_source/5531602
#   inflating: hpac_source/10393902
#   inflating: hpac_source/1799789
#   inflating: hpac_source/10534342
#   inflating: hpac_source/5451661
#   inflating: hpac_source/3033798
#   inflating: hpac_source/2488527
#   inflating: hpac_source/11576294
#   inflating: hpac_source/8715880
#   inflating: hpac_source/10938741
#   inflating: hpac_source/5221643
#   inflating: hpac_source/3301211
#   inflating: hpac_source/1435431
#   inflating: hpac_source/5209029
#   inflating: hpac_source/5314422
#   inflating: hpac_source/5275593
#   inflating: hpac_source/5375415
#   inflating: hpac_source/3156887
#   inflating: hpac_source/3261272
#   inflating: hpac_source/6380882
#   inflating: hpac_source/1418729
#   inflating: hpac_source/6397835
#   inflating: hpac_source/4352968
#   inflating: hpac_source/5901857
#   inflating: hpac_source/4631916
#   inflating: hpac_source/4452989
#   inflating: hpac_source/10694637
#   inflating: hpac_source/8244332
#   inflating: hpac_source/2108532
#   inflating: hpac_source/7032963
#   inflating: hpac_source/7348957
#   inflating: hpac_source/12422567
#   inflating: hpac_source/4336411
#   inflating: hpac_source/5992979
#   inflating: hpac_source/1473640
#   inflating: hpac_source/6416067
#   inflating: hpac_source/2193215
#   inflating: hpac_source/6517033
#   inflating: hpac_source/11687527
#   inflating: hpac_source/4850874
#   inflating: hpac_source/2803852
#   inflating: hpac_source/3720538
#   inflating: hpac_source/3949253
#   inflating: hpac_source/12029373
#   inflating: hpac_source/3461771
#   inflating: hpac_source/4538088
#   inflating: hpac_source/5948252
#   inflating: hpac_source/1910268
#   inflating: hpac_source/6681216
#   inflating: hpac_source/9931823
#   inflating: hpac_source/12037847
#   inflating: hpac_source/3588194
#   inflating: hpac_source/10691721
#   inflating: hpac_source/11432634
#   inflating: hpac_source/4387039
#   inflating: hpac_source/7499447
#   inflating: hpac_source/6537606
#   inflating: hpac_source/7996747
#   inflating: hpac_source/2545701
#   inflating: hpac_source/5366654
#   inflating: hpac_source/2920964
#   inflating: hpac_source/6848671
#   inflating: hpac_source/5839343
#   inflating: hpac_source/11405284
#   inflating: hpac_source/1759336
#   inflating: hpac_source/12384784
#   inflating: hpac_source/11310318
#   inflating: hpac_source/1890278
#   inflating: hpac_source/8894219
#   inflating: hpac_source/4944353
#   inflating: hpac_source/2847583
#   inflating: hpac_source/10759882
#   inflating: hpac_source/12675706
#   inflating: hpac_source/7706340
#   inflating: hpac_source/7331954
#   inflating: hpac_source/12286969
#   inflating: hpac_source/2821791
#   inflating: hpac_source/2869822
#   inflating: hpac_source/9539413
#   inflating: hpac_source/5571925
#   inflating: hpac_source/12723207
#   inflating: hpac_source/7093944
#   inflating: hpac_source/2525079
#   inflating: hpac_source/2181971
#   inflating: hpac_source/9210178
#   inflating: hpac_source/1478435
#   inflating: hpac_source/7765612
#   inflating: hpac_source/12122080
#   inflating: hpac_source/5734444
#   inflating: hpac_source/3230629
#   inflating: hpac_source/10172304
#   inflating: hpac_source/7106829
#   inflating: hpac_source/2636819
#   inflating: hpac_source/11310916
#   inflating: hpac_source/9534902
#   inflating: hpac_source/2951752
#   inflating: hpac_source/9885008
#   inflating: hpac_source/9171736
#   inflating: hpac_source/4952004
#   inflating: hpac_source/5508787
#   inflating: hpac_source/5185339
#   inflating: hpac_source/5630506
#   inflating: hpac_source/8212128
#   inflating: hpac_source/4056510
#   inflating: hpac_source/11597335
#   inflating: hpac_source/8070065
#   inflating: hpac_source/2677071
#   inflating: hpac_source/4671255
#   inflating: hpac_source/7911090
#   inflating: hpac_source/568920
#   inflating: hpac_source/10356038
#   inflating: hpac_source/3600240
#   inflating: hpac_source/10071063
#   inflating: hpac_source/10478544
#   inflating: hpac_source/11509504
#   inflating: hpac_source/5598810
#   inflating: hpac_source/12534319
#   inflating: hpac_source/3259017
#   inflating: hpac_source/3352579
#   inflating: hpac_source/7279137
#   inflating: hpac_source/4199405
#   inflating: hpac_source/7942959
#   inflating: hpac_source/2878508
#   inflating: hpac_source/3382730
#   inflating: hpac_source/2864157
#   inflating: hpac_source/7652572
#   inflating: hpac_source/8077072
#   inflating: hpac_source/6239584
#   inflating: hpac_source/9423659
#   inflating: hpac_source/4177371
#   inflating: hpac_source/6424952
#   inflating: hpac_source/5656526
#   inflating: hpac_source/12174251
#   inflating: hpac_source/5704487
#   inflating: hpac_source/8418747
#   inflating: hpac_source/2680628
#   inflating: hpac_source/12594829
#   inflating: hpac_source/9192339
#   inflating: hpac_source/10314883
#   inflating: hpac_source/1659049
#   inflating: hpac_source/9559192
#   inflating: hpac_source/3827361
#   inflating: hpac_source/11901553
#   inflating: hpac_source/7030061
#   inflating: hpac_source/6156096
#   inflating: hpac_source/2113521
#   inflating: hpac_source/11947346
#   inflating: hpac_source/10646540
#   inflating: hpac_source/5433488
#   inflating: hpac_source/12491627
#   inflating: hpac_source/7021321
#   inflating: hpac_source/9497393
#   inflating: hpac_source/5372865
#   inflating: hpac_source/4502916
#   inflating: hpac_source/3155057
#   inflating: hpac_source/11179823
#   inflating: hpac_source/9949308
#   inflating: hpac_source/3314398
#   inflating: hpac_source/7393391
#   inflating: hpac_source/2348374
#   inflating: hpac_source/6540559
#   inflating: hpac_source/9847126
#   inflating: hpac_source/4286260
#   inflating: hpac_source/12418293
#   inflating: hpac_source/9879629
#   inflating: hpac_source/4940363
#   inflating: hpac_source/9843586
#   inflating: hpac_source/4118228
#   inflating: hpac_source/4888053
#   inflating: hpac_source/11341916
#   inflating: hpac_source/4559080
#   inflating: hpac_source/6705236
#   inflating: hpac_source/10953425
#   inflating: hpac_source/6551619
#   inflating: hpac_source/12155770
#   inflating: hpac_source/7902641
#   inflating: hpac_source/2541990
#   inflating: hpac_source/5085079
#   inflating: hpac_source/7509067
#   inflating: hpac_source/10495441
#   inflating: hpac_source/4008900
#   inflating: hpac_source/5514922
#   inflating: hpac_source/11703507
#   inflating: hpac_source/3752127
#   inflating: hpac_source/7239613
#   inflating: hpac_source/9895438
#   inflating: hpac_source/12540608
#   inflating: hpac_source/1906756
#   inflating: hpac_source/12384770
#   inflating: hpac_source/3291403
#   inflating: hpac_source/1238276
#   inflating: hpac_source/12261758
#   inflating: hpac_source/2861287
#   inflating: hpac_source/5317298
#   inflating: hpac_source/6867457
#   inflating: hpac_source/3681835
#   inflating: hpac_source/10156165
#   inflating: hpac_source/6595606
#   inflating: hpac_source/12640415
#   inflating: hpac_source/2040304
#   inflating: hpac_source/3711624
#   inflating: hpac_source/7553649
#   inflating: hpac_source/10061453
#   inflating: hpac_source/3464658
#   inflating: hpac_source/5490565
#   inflating: hpac_source/3670795
#   inflating: hpac_source/9595314
#   inflating: hpac_source/1297132
#   inflating: hpac_source/7356852
#   inflating: hpac_source/11596677
#   inflating: hpac_source/6530078
#   inflating: hpac_source/3671475
#   inflating: hpac_source/3576029
#   inflating: hpac_source/3200874
#   inflating: hpac_source/6293722
#   inflating: hpac_source/7396889
#   inflating: hpac_source/9711740
#   inflating: hpac_source/11339666
#   inflating: hpac_source/3815401
#   inflating: hpac_source/7659364
#   inflating: hpac_source/7398573
#   inflating: hpac_source/10412157
#   inflating: hpac_source/11869765
#   inflating: hpac_source/3122901
#   inflating: hpac_source/11649653
#   inflating: hpac_source/12250671
#   inflating: hpac_source/1302631
#   inflating: hpac_source/11445761
#   inflating: hpac_source/2829366
#   inflating: hpac_source/12056279
#   inflating: hpac_source/4052940
#   inflating: hpac_source/6250520
#   inflating: hpac_source/3687590
#   inflating: hpac_source/12618766
#   inflating: hpac_source/12048171
#   inflating: hpac_source/7207316
#   inflating: hpac_source/12097370
#   inflating: hpac_source/2211437
#   inflating: hpac_source/5802905
#   inflating: hpac_source/3194166
#   inflating: hpac_source/12127966
#   inflating: hpac_source/11732876
#   inflating: hpac_source/7180273
#   inflating: hpac_source/5160069
#   inflating: hpac_source/7236663
#   inflating: hpac_source/2988802
#   inflating: hpac_source/3892573
#   inflating: hpac_source/6227640
#   inflating: hpac_source/8812843
#   inflating: hpac_source/7355085
#   inflating: hpac_source/9497199
#   inflating: hpac_source/3367460
#   inflating: hpac_source/1253327
#   inflating: hpac_source/6895112
#   inflating: hpac_source/2272165
#   inflating: hpac_source/10197868
#   inflating: hpac_source/9681367
#   inflating: hpac_source/6741728
#   inflating: hpac_source/4513404
#   inflating: hpac_source/1327112
#   inflating: hpac_source/9883101
#   inflating: hpac_source/1082327
#   inflating: hpac_source/8136950
#   inflating: hpac_source/10046249
#   inflating: hpac_source/10960069
#   inflating: hpac_source/3696086
#   inflating: hpac_source/6438199
#   inflating: hpac_source/10543025
#   inflating: hpac_source/3590508
#   inflating: hpac_source/2115884
#   inflating: hpac_source/3078695
#   inflating: hpac_source/12580881
#   inflating: hpac_source/9136801
#   inflating: hpac_source/7194025
#   inflating: hpac_source/7264012
#   inflating: hpac_source/3359539
#   inflating: hpac_source/4832897
#   inflating: hpac_source/6829225
#   inflating: hpac_source/12193232
#   inflating: hpac_source/9574410
#   inflating: hpac_source/7321938
#   inflating: hpac_source/8317174
#   inflating: hpac_source/7359822
#   inflating: hpac_source/9268892
#   inflating: hpac_source/3695431
#   inflating: hpac_source/9541531
#   inflating: hpac_source/8492318
#   inflating: hpac_source/3091330
#   inflating: hpac_source/3186201
#   inflating: hpac_source/11576055
#   inflating: hpac_source/5953883
#   inflating: hpac_source/5944834
#   inflating: hpac_source/7129650
#   inflating: hpac_source/8346510
#   inflating: hpac_source/2659382
#   inflating: hpac_source/10059067
#   inflating: hpac_source/2625638
#   inflating: hpac_source/11488607
#   inflating: hpac_source/3776528
#   inflating: hpac_source/7145944
#   inflating: hpac_source/11845903
#   inflating: hpac_source/6176805
#   inflating: hpac_source/8920699
#   inflating: hpac_source/12418409
#   inflating: hpac_source/11613089
#   inflating: hpac_source/5124789
#   inflating: hpac_source/3489765
#   inflating: hpac_source/10829574
#   inflating: hpac_source/10738283
#   inflating: hpac_source/11480658
#   inflating: hpac_source/3878237
#   inflating: hpac_source/6052924
#   inflating: hpac_source/5310243
#   inflating: hpac_source/7781656
#   inflating: hpac_source/12254225
#   inflating: hpac_source/4692808
#   inflating: hpac_source/8085361
#   inflating: hpac_source/8784252
#   inflating: hpac_source/7418863
#   inflating: hpac_source/12572534
#   inflating: hpac_source/6069701
#   inflating: hpac_source/6625549
#   inflating: hpac_source/8242660
#   inflating: hpac_source/9410443
#   inflating: hpac_source/5084355
#   inflating: hpac_source/8948949
#   inflating: hpac_source/3204040
#   inflating: hpac_source/11095344
#   inflating: hpac_source/9366422
#   inflating: hpac_source/6430556
#   inflating: hpac_source/7406357
#   inflating: hpac_source/8205395
#   inflating: hpac_source/12661568
#   inflating: hpac_source/11608899
#   inflating: hpac_source/2488382
#   inflating: hpac_source/7649330
#   inflating: hpac_source/8767239
#   inflating: hpac_source/5245791
#   inflating: hpac_source/3114699
#   inflating: hpac_source/7369029
#   inflating: hpac_source/5512225
#   inflating: hpac_source/8643318
#   inflating: hpac_source/8445710
#   inflating: hpac_source/9846038
#   inflating: hpac_source/848459
#   inflating: hpac_source/2473124
#   inflating: hpac_source/1252201
#   inflating: hpac_source/6388644
#   inflating: hpac_source/5547027
#   inflating: hpac_source/3894670
#   inflating: hpac_source/2766881
#   inflating: hpac_source/8842166
#   inflating: hpac_source/3830573
#   inflating: hpac_source/2239606
#   inflating: hpac_source/9030273
#   inflating: hpac_source/11377219
#   inflating: hpac_source/7238190
#   inflating: hpac_source/3127828
#   inflating: hpac_source/2892079
#   inflating: hpac_source/3491751
#   inflating: hpac_source/10942134
#   inflating: hpac_source/3369393
#   inflating: hpac_source/12330249
#   inflating: hpac_source/2976183
#   inflating: hpac_source/5328670
#   inflating: hpac_source/7822591
#   inflating: hpac_source/6160197
#   inflating: hpac_source/12010037
#   inflating: hpac_source/7775473
#   inflating: hpac_source/11126344
#   inflating: hpac_source/3509311
#   inflating: hpac_source/7625285
#   inflating: hpac_source/6482502
#   inflating: hpac_source/2419154
#   inflating: hpac_source/6179288
#   inflating: hpac_source/6874047
#   inflating: hpac_source/2766412
#   inflating: hpac_source/3257728
#   inflating: hpac_source/4747014
#   inflating: hpac_source/4634460
#   inflating: hpac_source/12379626
#   inflating: hpac_source/3309044
#   inflating: hpac_source/6177312
#   inflating: hpac_source/4802433
#   inflating: hpac_source/1934693
#   inflating: hpac_source/2324803
#   inflating: hpac_source/5726340
#   inflating: hpac_source/4757286
#   inflating: hpac_source/5781867
#   inflating: hpac_source/7119832
#   inflating: hpac_source/10906244
#   inflating: hpac_source/9944246
#   inflating: hpac_source/8455911
#   inflating: hpac_source/6925307
#   inflating: hpac_source/9166918
#   inflating: hpac_source/9823464
#   inflating: hpac_source/2913342
#   inflating: hpac_source/6051100
#   inflating: hpac_source/7323806
#   inflating: hpac_source/8214822
#   inflating: hpac_source/12006704
#   inflating: hpac_source/2529223
#   inflating: hpac_source/12511891
#   inflating: hpac_source/6662077
#   inflating: hpac_source/8913014
#   inflating: hpac_source/9764714
#   inflating: hpac_source/7506814
#   inflating: hpac_source/6089918
#   inflating: hpac_source/4740655
#   inflating: hpac_source/8592631
#   inflating: hpac_source/12387596
#   inflating: hpac_source/11052343
#   inflating: hpac_source/2870796
#   inflating: hpac_source/10908588
#   inflating: hpac_source/5937367
#   inflating: hpac_source/11075753
#   inflating: hpac_source/6281684
#   inflating: hpac_source/11917431
#   inflating: hpac_source/12595306
#   inflating: hpac_source/10290261
#   inflating: hpac_source/6752556
#   inflating: hpac_source/4066376
#   inflating: hpac_source/3714507
#   inflating: hpac_source/9275944
#   inflating: hpac_source/5539033
#   inflating: hpac_source/2792896
#   inflating: hpac_source/5372862
#   inflating: hpac_source/9947295
#   inflating: hpac_source/12045651
#   inflating: hpac_source/9851276
#   inflating: hpac_source/7854949
#   inflating: hpac_source/9053177
#   inflating: hpac_source/5110113
#   inflating: hpac_source/10379484
#   inflating: hpac_source/7555129
#   inflating: hpac_source/7960000
#   inflating: hpac_source/3962270
#   inflating: hpac_source/9707080
#   inflating: hpac_source/7979911
#   inflating: hpac_source/5141577
#   inflating: hpac_source/8369504
#   inflating: hpac_source/8121574
#   inflating: hpac_source/2209631
#   inflating: hpac_source/5199553
#   inflating: hpac_source/8189627
#   inflating: hpac_source/6500048
#   inflating: hpac_source/7306987
#   inflating: hpac_source/8132163
#   inflating: hpac_source/8951255
#   inflating: hpac_source/5601074
#   inflating: hpac_source/4158739
#   inflating: hpac_source/8296284
#   inflating: hpac_source/8930050
#   inflating: hpac_source/6251439
#   inflating: hpac_source/9018089
#   inflating: hpac_source/3929974
#   inflating: hpac_source/6284302
#   inflating: hpac_source/8481166
#   inflating: hpac_source/2792862
#   inflating: hpac_source/1216972
#   inflating: hpac_source/8295633
#   inflating: hpac_source/4411448
#   inflating: hpac_source/6735662
#   inflating: hpac_source/2527943
#   inflating: hpac_source/3742174
#   inflating: hpac_source/3027502
#   inflating: hpac_source/5473199
#   inflating: hpac_source/7063167
#   inflating: hpac_source/12156334
#   inflating: hpac_source/6311861
#   inflating: hpac_source/3864657
#   inflating: hpac_source/9065085
#   inflating: hpac_source/5452028
#   inflating: hpac_source/2005155
#   inflating: hpac_source/7915053
#   inflating: hpac_source/8140315
#   inflating: hpac_source/4523854
#   inflating: hpac_source/7539057
#   inflating: hpac_source/9852063
#   inflating: hpac_source/8279046
#   inflating: hpac_source/7781669
#   inflating: hpac_source/9836526
#   inflating: hpac_source/10690855
#   inflating: hpac_source/9706704
#   inflating: hpac_source/4617424
#   inflating: hpac_source/5671555
#   inflating: hpac_source/3604283
#   inflating: hpac_source/5560850
#   inflating: hpac_source/7774555
#   inflating: hpac_source/5156396
#   inflating: hpac_source/8344876
#   inflating: hpac_source/10074172
#   inflating: hpac_source/7580044
#   inflating: hpac_source/6051590
#   inflating: hpac_source/6963182
#   inflating: hpac_source/1310569
#   inflating: hpac_source/8699030
#   inflating: hpac_source/2898785
#   inflating: hpac_source/6764696
#   inflating: hpac_source/4026036
#   inflating: hpac_source/3258794
#   inflating: hpac_source/4705255
#   inflating: hpac_source/1902305
#   inflating: hpac_source/1654335
#   inflating: hpac_source/7611276
#   inflating: hpac_source/3409051
#   inflating: hpac_source/8534854
#   inflating: hpac_source/6744291
#   inflating: hpac_source/8007766
#   inflating: hpac_source/7206459
#   inflating: hpac_source/7050721
#   inflating: hpac_source/11499578
#   inflating: hpac_source/7238356
#   inflating: hpac_source/11758208
#   inflating: hpac_source/9127184
#   inflating: hpac_source/12413211
#   inflating: hpac_source/11031872
#   inflating: hpac_source/4030992
#   inflating: hpac_source/8521775
#   inflating: hpac_source/12125851
#   inflating: hpac_source/4406254
#   inflating: hpac_source/3073079
#   inflating: hpac_source/9955933
#   inflating: hpac_source/2763169
#   inflating: hpac_source/3048204
#   inflating: hpac_source/3234041
#   inflating: hpac_source/3464656
#   inflating: hpac_source/7700871
#   inflating: hpac_source/4322212
#   inflating: hpac_source/3573767
#   inflating: hpac_source/7345645
#   inflating: hpac_source/7383569
#   inflating: hpac_source/12370590
#   inflating: hpac_source/1904833
#   inflating: hpac_source/9048152
#   inflating: hpac_source/5147219
#   inflating: hpac_source/3683750
#   inflating: hpac_source/2544888
#   inflating: hpac_source/4465706
#   inflating: hpac_source/1377466
#   inflating: hpac_source/6132985
#   inflating: hpac_source/3822883
#   inflating: hpac_source/11014309
#   inflating: hpac_source/7780746
#   inflating: hpac_source/11305630
#   inflating: hpac_source/9269976
#   inflating: hpac_source/2757952
#   inflating: hpac_source/12644289
#   inflating: hpac_source/7682197
#   inflating: hpac_source/2766629
#   inflating: hpac_source/10212462
#   inflating: hpac_source/8594399
#   inflating: hpac_source/7182176
#   inflating: hpac_source/7056619
#   inflating: hpac_source/11808300
#   inflating: hpac_source/9348519
#   inflating: hpac_source/7573072
#   inflating: hpac_source/11773814
#   inflating: hpac_source/10265530
#   inflating: hpac_source/4649233
#   inflating: hpac_source/5723851
#   inflating: hpac_source/9778170
#   inflating: hpac_source/4033941
#   inflating: hpac_source/12340553
#   inflating: hpac_source/10357110
#   inflating: hpac_source/7210397
#   inflating: hpac_source/4779144
#   inflating: hpac_source/5260414
#   inflating: hpac_source/9690647
#   inflating: hpac_source/7250675
#   inflating: hpac_source/5190423
#   inflating: hpac_source/12400050
#   inflating: hpac_source/12434265
#   inflating: hpac_source/7330424
#   inflating: hpac_source/4047498
#   inflating: hpac_source/6987567
#   inflating: hpac_source/7620994
#   inflating: hpac_source/7674278
#   inflating: hpac_source/8532706
#   inflating: hpac_source/8023358
#   inflating: hpac_source/4875930
#   inflating: hpac_source/10600955
#   inflating: hpac_source/9559168
#   inflating: hpac_source/11376594
#   inflating: hpac_source/8107883
#   inflating: hpac_source/2792057
#   inflating: hpac_source/12119697
#   inflating: hpac_source/2959969
#   inflating: hpac_source/4831288
#   inflating: hpac_source/6276212
#   inflating: hpac_source/6206165
#   inflating: hpac_source/3696612
#   inflating: hpac_source/4180526
#   inflating: hpac_source/8995415
#   inflating: hpac_source/6099945
#   inflating: hpac_source/2327011
#   inflating: hpac_source/7285986
#   inflating: hpac_source/10597058
#   inflating: hpac_source/12057369
#   inflating: hpac_source/12361240
#   inflating: hpac_source/6525134
#   inflating: hpac_source/1698972
#   inflating: hpac_source/3048694
#   inflating: hpac_source/10157429
#   inflating: hpac_source/5246122
#   inflating: hpac_source/3745956
#   inflating: hpac_source/6602953
#   inflating: hpac_source/3138465
#   inflating: hpac_source/8759500
#   inflating: hpac_source/12178492
#   inflating: hpac_source/7680062
#   inflating: hpac_source/1542044
#   inflating: hpac_source/2432522
#   inflating: hpac_source/3997979
#   inflating: hpac_source/4188579
#   inflating: hpac_source/8465321
#   inflating: hpac_source/12225284
#   inflating: hpac_source/6374295
#   inflating: hpac_source/7767379
#   inflating: hpac_source/2242356
#   inflating: hpac_source/12242520
#   inflating: hpac_source/7682351
#   inflating: hpac_source/2273411
#   inflating: hpac_source/10235086
#   inflating: hpac_source/3382168
#   inflating: hpac_source/8404772
#   inflating: hpac_source/12000856
#   inflating: hpac_source/11265495
#   inflating: hpac_source/8138808
#   inflating: hpac_source/12184849
#   inflating: hpac_source/12339339
#   inflating: hpac_source/3658105
#   inflating: hpac_source/4498491
#   inflating: hpac_source/1024910
#   inflating: hpac_source/5098956
#   inflating: hpac_source/4554301
#   inflating: hpac_source/9357737
#   inflating: hpac_source/12588212
#   inflating: hpac_source/2494981
#   inflating: hpac_source/5649998
#   inflating: hpac_source/7380916
#   inflating: hpac_source/12608152
#   inflating: hpac_source/4810339
#   inflating: hpac_source/4241632
#   inflating: hpac_source/1969433
#   inflating: hpac_source/10298495
#   inflating: hpac_source/881961
#   inflating: hpac_source/8557533
#   inflating: hpac_source/8406217
#   inflating: hpac_source/3333918
#   inflating: hpac_source/7698056
#   inflating: hpac_source/10509490
#   inflating: hpac_source/6075191
#   inflating: hpac_source/4656680
#   inflating: hpac_source/11795956
#   inflating: hpac_source/7705958
#   inflating: hpac_source/8551059
#   inflating: hpac_source/12652585
#   inflating: hpac_source/1747202
#   inflating: hpac_source/8408510
#   inflating: hpac_source/6238493
#   inflating: hpac_source/11672615
#   inflating: hpac_source/11924625
#   inflating: hpac_source/6566298
#   inflating: hpac_source/12554837
#   inflating: hpac_source/10174660
#   inflating: hpac_source/3590959
#   inflating: hpac_source/8092925
#   inflating: hpac_source/6595253
#   inflating: hpac_source/2877585
#   inflating: hpac_source/4303992
#   inflating: hpac_source/10861662
#   inflating: hpac_source/2720467
#   inflating: hpac_source/11502915
#   inflating: hpac_source/5578435
#   inflating: hpac_source/11160103
#   inflating: hpac_source/3126594
#   inflating: hpac_source/7868927
#   inflating: hpac_source/4124073
#   inflating: hpac_source/3931949
#   inflating: hpac_source/2838813
#   inflating: hpac_source/12172351
#   inflating: hpac_source/6535963
#   inflating: hpac_source/8762584
#   inflating: hpac_source/7128129
#   inflating: hpac_source/12545945
#   inflating: hpac_source/10443398
#   inflating: hpac_source/8433907
#   inflating: hpac_source/6073430
#   inflating: hpac_source/7927153
#   inflating: hpac_source/10689186
#   inflating: hpac_source/11613848
#   inflating: hpac_source/5448742
#   inflating: hpac_source/6290196
#   inflating: hpac_source/10804691
#   inflating: hpac_source/8521578
#   inflating: hpac_source/5292156
#   inflating: hpac_source/7547278
#   inflating: hpac_source/6275804
#   inflating: hpac_source/4731290
#   inflating: hpac_source/11281610
#   inflating: hpac_source/12726582
#   inflating: hpac_source/8493005
#   inflating: hpac_source/10470388
#   inflating: hpac_source/3056301
#   inflating: hpac_source/5005327
#   inflating: hpac_source/6916577
#   inflating: hpac_source/7420802
#   inflating: hpac_source/7439113
#   inflating: hpac_source/4346768
#   inflating: hpac_source/3158913
#   inflating: hpac_source/3296617
#   inflating: hpac_source/4801280
#   inflating: hpac_source/7862277
#   inflating: hpac_source/2982955
#   inflating: hpac_source/3312608
#   inflating: hpac_source/6689411
#   inflating: hpac_source/4833342
#   inflating: hpac_source/7427029
#   inflating: hpac_source/3047273
#   inflating: hpac_source/5229420
#   inflating: hpac_source/11729853
#   inflating: hpac_source/8832015
#   inflating: hpac_source/3681804
#   inflating: hpac_source/10759847
#   inflating: hpac_source/7264229
#   inflating: hpac_source/8239754
#   inflating: hpac_source/6160969
#   inflating: hpac_source/7828855
#   inflating: hpac_source/7069833
#   inflating: hpac_source/8233894
#   inflating: hpac_source/10935898
#   inflating: hpac_source/10603171
#   inflating: hpac_source/7670045
#   inflating: hpac_source/6490005
#   inflating: hpac_source/9396601
#   inflating: hpac_source/5578899
#   inflating: hpac_source/6084893
#   inflating: hpac_source/7189555
#   inflating: hpac_source/3962410
#   inflating: hpac_source/8920690
#   inflating: hpac_source/4439670
#   inflating: hpac_source/9281730
#   inflating: hpac_source/2846652
#   inflating: hpac_source/818576
#   inflating: hpac_source/6959029
#   inflating: hpac_source/2721919
#   inflating: hpac_source/9008649
#   inflating: hpac_source/12171978
#   inflating: hpac_source/3733783
#   inflating: hpac_source/7903100
#   inflating: hpac_source/5734475
#   inflating: hpac_source/4021017
#   inflating: hpac_source/3652632
#   inflating: hpac_source/8880628
#   inflating: hpac_source/4297581
#   inflating: hpac_source/7574892
#   inflating: hpac_source/10631281
#   inflating: hpac_source/4379141
#   inflating: hpac_source/6767819
#   inflating: hpac_source/1606324
#   inflating: hpac_source/6926918
#   inflating: hpac_source/5017424
#   inflating: hpac_source/2963493
#   inflating: hpac_source/5134720
#   inflating: hpac_source/9762045
#   inflating: hpac_source/5592371
#   inflating: hpac_source/2577853
#   inflating: hpac_source/4845336
#   inflating: hpac_source/4809019
#   inflating: hpac_source/4193758
#   inflating: hpac_source/11632303
#   inflating: hpac_source/4074443
#   inflating: hpac_source/3024183
#   inflating: hpac_source/12468121
#   inflating: hpac_source/6036202
#   inflating: hpac_source/6894801
#   inflating: hpac_source/10873161
#   inflating: hpac_source/2641710
#   inflating: hpac_source/7918910
#   inflating: hpac_source/7106672
#   inflating: hpac_source/8970584
#   inflating: hpac_source/3558929
#   inflating: hpac_source/1852393
#   inflating: hpac_source/11214059
#   inflating: hpac_source/11727757
#   inflating: hpac_source/3013701
#   inflating: hpac_source/5111003
#   inflating: hpac_source/4060043
#   inflating: hpac_source/2558276
#   inflating: hpac_source/4812809
#   inflating: hpac_source/2921070
#   inflating: hpac_source/10845631
#   inflating: hpac_source/7225887
#   inflating: hpac_source/4430997
#   inflating: hpac_source/12055401
#   inflating: hpac_source/8007106
#   inflating: hpac_source/2890388
#   inflating: hpac_source/12268274
#   inflating: hpac_source/7135450
#   inflating: hpac_source/8062591
#   inflating: hpac_source/10810853
#   inflating: hpac_source/9613950
#   inflating: hpac_source/12370751
#   inflating: hpac_source/7302343
#   inflating: hpac_source/8822845
#   inflating: hpac_source/12085214
#   inflating: hpac_source/1695000
#   inflating: hpac_source/6973910
#   inflating: hpac_source/2005967
#   inflating: hpac_source/6896938
#   inflating: hpac_source/2563457
#   inflating: hpac_source/3780292
#   inflating: hpac_source/9201231
#   inflating: hpac_source/9659988
#   inflating: hpac_source/6078014
#   inflating: hpac_source/5787164
#   inflating: hpac_source/12201472
#   inflating: hpac_source/11681878
#   inflating: hpac_source/2454353
#   inflating: hpac_source/4647168
#   inflating: hpac_source/2400083
#   inflating: hpac_source/12153822
#   inflating: hpac_source/8462567
#   inflating: hpac_source/6215323
#   inflating: hpac_source/11686053
#   inflating: hpac_source/2870906
#   inflating: hpac_source/12275197
#   inflating: hpac_source/8500253
#   inflating: hpac_source/8707789
#   inflating: hpac_source/12331537
#   inflating: hpac_source/2393528
#   inflating: hpac_source/7454173
#   inflating: hpac_source/4697745
#   inflating: hpac_source/5576751
#   inflating: hpac_source/3502969
#   inflating: hpac_source/8197521
#   inflating: hpac_source/3677129
#   inflating: hpac_source/4436056
#   inflating: hpac_source/4202304
#   inflating: hpac_source/9830089
#   inflating: hpac_source/7139097
#   inflating: hpac_source/4038754
#   inflating: hpac_source/4228239
#   inflating: hpac_source/6317196
#   inflating: hpac_source/11067862
#   inflating: hpac_source/5761825
#   inflating: hpac_source/6343246
#   inflating: hpac_source/7134788
#   inflating: hpac_source/5474180
#   inflating: hpac_source/7370909
#   inflating: hpac_source/11058683
#   inflating: hpac_source/12005947
#   inflating: hpac_source/2765609
#   inflating: hpac_source/8846964
#   inflating: hpac_source/7147874
#   inflating: hpac_source/11542407
#   inflating: hpac_source/10150439
#   inflating: hpac_source/7556590
#   inflating: hpac_source/12341472
#   inflating: hpac_source/11095375
#   inflating: hpac_source/1630814
#   inflating: hpac_source/12691125
#   inflating: hpac_source/6970937
#   inflating: hpac_source/4363241
#   inflating: hpac_source/2599181
#   inflating: hpac_source/448652
#   inflating: hpac_source/9455624
#   inflating: hpac_source/12228568
#   inflating: hpac_source/9991117
#   inflating: hpac_source/5749687
#   inflating: hpac_source/7237780
#   inflating: hpac_source/5341272
#   inflating: hpac_source/4008135
#   inflating: hpac_source/2988833
#   inflating: hpac_source/5660885
#   inflating: hpac_source/5760903
#   inflating: hpac_source/2092045
#   inflating: hpac_source/9197484
#   inflating: hpac_source/7051863
#   inflating: hpac_source/3040638
#   inflating: hpac_source/3400542
#   inflating: hpac_source/1442303
#   inflating: hpac_source/6020199
#   inflating: hpac_source/12361081
#   inflating: hpac_source/5682100
#   inflating: hpac_source/8845729
#   inflating: hpac_source/3780602
#   inflating: hpac_source/4142259
#   inflating: hpac_source/9413203
#   inflating: hpac_source/2523525
#   inflating: hpac_source/2897161
#   inflating: hpac_source/4192010
#   inflating: hpac_source/12553440
#   inflating: hpac_source/5678610
#   inflating: hpac_source/6276685
#   inflating: hpac_source/11460241
#   inflating: hpac_source/6819481
#   inflating: hpac_source/10240442
#   inflating: hpac_source/8150941
#   inflating: hpac_source/2916854
#   inflating: hpac_source/4507035
#   inflating: hpac_source/3030917
#   inflating: hpac_source/3257514
#   inflating: hpac_source/2449418
#   inflating: hpac_source/1488286
#   inflating: hpac_source/2272702
#   inflating: hpac_source/7830268
#   inflating: hpac_source/6224490
#   inflating: hpac_source/6969442
#   inflating: hpac_source/5342093
#   inflating: hpac_source/7413224
#   inflating: hpac_source/9842805
#   inflating: hpac_source/5070728
#   inflating: hpac_source/9985341
#   inflating: hpac_source/7732188
#   inflating: hpac_source/2318855
#   inflating: hpac_source/12323462
#   inflating: hpac_source/6571673
#   inflating: hpac_source/7234561
#   inflating: hpac_source/5423045
#   inflating: hpac_source/1802279
#   inflating: hpac_source/7291911
#   inflating: hpac_source/11187194
#   inflating: hpac_source/10289514
#   inflating: hpac_source/9729183
#   inflating: hpac_source/12356267
#   inflating: hpac_source/12540265
#   inflating: hpac_source/10852820
#   inflating: hpac_source/7515869
#   inflating: hpac_source/10102421
#   inflating: hpac_source/3286220
#   inflating: hpac_source/4311498
#   inflating: hpac_source/10006107
#   inflating: hpac_source/4799554
#   inflating: hpac_source/6410963
#   inflating: hpac_source/12458581
#   inflating: hpac_source/12660686
#   inflating: hpac_source/7903563
#   inflating: hpac_source/8248354
#   inflating: hpac_source/2820023
#   inflating: hpac_source/8827150
#   inflating: hpac_source/11822695
#   inflating: hpac_source/9742213
#   inflating: hpac_source/6703331
#   inflating: hpac_source/2525619
#   inflating: hpac_source/12664828
#   inflating: hpac_source/10113553
#   inflating: hpac_source/1934232
#   inflating: hpac_source/11816692
#   inflating: hpac_source/3965064
#   inflating: hpac_source/7077556
#   inflating: hpac_source/3242469
#   inflating: hpac_source/2616242
#   inflating: hpac_source/8126760
#   inflating: hpac_source/5182318
#   inflating: hpac_source/10842621
#   inflating: hpac_source/2614515
#   inflating: hpac_source/5351817
#   inflating: hpac_source/11123899
#   inflating: hpac_source/4466719
#   inflating: hpac_source/3712407
#   inflating: hpac_source/12063356
#   inflating: hpac_source/11853602
#   inflating: hpac_source/11345548
#   inflating: hpac_source/9636670
#   inflating: hpac_source/1309011
#   inflating: hpac_source/6373088
#   inflating: hpac_source/5920543
#   inflating: hpac_source/7776001
#   inflating: hpac_source/7773573
#   inflating: hpac_source/7896856
#   inflating: hpac_source/2860397
#   inflating: hpac_source/204889
#   inflating: hpac_source/9109428
#   inflating: hpac_source/9484110
#   inflating: hpac_source/2484919
#   inflating: hpac_source/12531837
#   inflating: hpac_source/6441997
#   inflating: hpac_source/1874000
#   inflating: hpac_source/5419113
#   inflating: hpac_source/8445148
#   inflating: hpac_source/6836005
#   inflating: hpac_source/5163040
#   inflating: hpac_source/3295253
#   inflating: hpac_source/8052767
#   inflating: hpac_source/6973113
#   inflating: hpac_source/7890993
#   inflating: hpac_source/4139169
#   inflating: hpac_source/4606755
#   inflating: hpac_source/1529327
#   inflating: hpac_source/8513449
#   inflating: hpac_source/3025600
#   inflating: hpac_source/5970001
#   inflating: hpac_source/9888721
#   inflating: hpac_source/9699150
#   inflating: hpac_source/1089507
#   inflating: hpac_source/6531168
#   inflating: hpac_source/3014147
#   inflating: hpac_source/8578144
#   inflating: hpac_source/2315749
#   inflating: hpac_source/6711056
#   inflating: hpac_source/7583436
#   inflating: hpac_source/3175230
#   inflating: hpac_source/12078980
#   inflating: hpac_source/4378060
#   inflating: hpac_source/12389865
#   inflating: hpac_source/4070474
#   inflating: hpac_source/12586176
#   inflating: hpac_source/5594849
#   inflating: hpac_source/8127222
#   inflating: hpac_source/11135550
#   inflating: hpac_source/5519253
#   inflating: hpac_source/9881658
#   inflating: hpac_source/7702722
#   inflating: hpac_source/2653642
#   inflating: hpac_source/6797698
#   inflating: hpac_source/3409094
#   inflating: hpac_source/7817475
#   inflating: hpac_source/9418082
#   inflating: hpac_source/11028967
#   inflating: hpac_source/8482342
#   inflating: hpac_source/3700760
#   inflating: hpac_source/3491760
#   inflating: hpac_source/11467867
#   inflating: hpac_source/8705227
#   inflating: hpac_source/2788357
#   inflating: hpac_source/4022661
#   inflating: hpac_source/6799530
#   inflating: hpac_source/3202729
#   inflating: hpac_source/3726090
#   inflating: hpac_source/6362932
#   inflating: hpac_source/9567835
#   inflating: hpac_source/7743120
#   inflating: hpac_source/3392104
#   inflating: hpac_source/10197268
#   inflating: hpac_source/10863556
#   inflating: hpac_source/2487566
#   inflating: hpac_source/4789356
#   inflating: hpac_source/3862101
#   inflating: hpac_source/4910617
#   inflating: hpac_source/7826564
#   inflating: hpac_source/2485655
#   inflating: hpac_source/3722054
#   inflating: hpac_source/8751593
#   inflating: hpac_source/7789899
#   inflating: hpac_source/9285707
#   inflating: hpac_source/2280240
#   inflating: hpac_source/3908458
#   inflating: hpac_source/1580536
#   inflating: hpac_source/11011227
#   inflating: hpac_source/3405833
#   inflating: hpac_source/3674555
#   inflating: hpac_source/12315769
#   inflating: hpac_source/12623515
#   inflating: hpac_source/9914351
#   inflating: hpac_source/3804313
#   inflating: hpac_source/6278176
#   inflating: hpac_source/4200498
#   inflating: hpac_source/10938922
#   inflating: hpac_source/2494727
#   inflating: hpac_source/3707313
#   inflating: hpac_source/7029348
#   inflating: hpac_source/11380829
#   inflating: hpac_source/10000036
#   inflating: hpac_source/3961430
#   inflating: hpac_source/6190982
#   inflating: hpac_source/12645535
#   inflating: hpac_source/5033828
#   inflating: hpac_source/8466568
#   inflating: hpac_source/1833165
#   inflating: hpac_source/7231448
#   inflating: hpac_source/7554802
#   inflating: hpac_source/7163216
#   inflating: hpac_source/6692608
#   inflating: hpac_source/6253199
#   inflating: hpac_source/2725380
#   inflating: hpac_source/3712453
#   inflating: hpac_source/3661027
#   inflating: hpac_source/3185886
#   inflating: hpac_source/6701600
#   inflating: hpac_source/6078629
#   inflating: hpac_source/6658349
#   inflating: hpac_source/4829815
#   inflating: hpac_source/7701563
#   inflating: hpac_source/10589932
#   inflating: hpac_source/8657570
#   inflating: hpac_source/4188515
#   inflating: hpac_source/12696965
#   inflating: hpac_source/6873697
#   inflating: hpac_source/9647481
#   inflating: hpac_source/5104582
#   inflating: hpac_source/11674545
#   inflating: hpac_source/8752184
#   inflating: hpac_source/6140959
#   inflating: hpac_source/2959139
#   inflating: hpac_source/12558453
#   inflating: hpac_source/3947152
#   inflating: hpac_source/3724303
#   inflating: hpac_source/8655829
#   inflating: hpac_source/9880940
#   inflating: hpac_source/7633715
#   inflating: hpac_source/2901424
#   inflating: hpac_source/7706574
#   inflating: hpac_source/3238042
#   inflating: hpac_source/6932113
#   inflating: hpac_source/2020421
#   inflating: hpac_source/7634154
#   inflating: hpac_source/12520911
#   inflating: hpac_source/7677233
#   inflating: hpac_source/3217069
#   inflating: hpac_source/4791309
#   inflating: hpac_source/9283808
#   inflating: hpac_source/7162532
#   inflating: hpac_source/11853000
#   inflating: hpac_source/7305931
#   inflating: hpac_source/3677714
#   inflating: hpac_source/8967938
#   inflating: hpac_source/6181408
#   inflating: hpac_source/9641120
#   inflating: hpac_source/12620754
#   inflating: hpac_source/9581782
#   inflating: hpac_source/9479829
#   inflating: hpac_source/11746959
#   inflating: hpac_source/7279703
#   inflating: hpac_source/2934195
#   inflating: hpac_source/9500967
#   inflating: hpac_source/10579324
#   inflating: hpac_source/6600230
#   inflating: hpac_source/10153481
#   inflating: hpac_source/4491742
#   inflating: hpac_source/12361648
#   inflating: hpac_source/2426718
#   inflating: hpac_source/8369939
#   inflating: hpac_source/10913535
#   inflating: hpac_source/7407489
#   inflating: hpac_source/9685769
#   inflating: hpac_source/5806361
#   inflating: hpac_source/7590081
#   inflating: hpac_source/5105808
#   inflating: hpac_source/12403827
#   inflating: hpac_source/7395494
#   inflating: hpac_source/4032661
#   inflating: hpac_source/8235902
#   inflating: hpac_source/10521639
#   inflating: hpac_source/2945330
#   inflating: hpac_source/7908789
#   inflating: hpac_source/2700457
#   inflating: hpac_source/7208760
#   inflating: hpac_source/5821785
#   inflating: hpac_source/8854066
#   inflating: hpac_source/2821535
#   inflating: hpac_source/8942085
#   inflating: hpac_source/7606062
#   inflating: hpac_source/7873356
#   inflating: hpac_source/7323609
#   inflating: hpac_source/4105191
#   inflating: hpac_source/12053335
#   inflating: hpac_source/6735297
#   inflating: hpac_source/5378959
#   inflating: hpac_source/5455892
#   inflating: hpac_source/10140062
#   inflating: hpac_source/8772113
#   inflating: hpac_source/1841949
#   inflating: hpac_source/3356719
#   inflating: hpac_source/10620166
#   inflating: hpac_source/7632859
#   inflating: hpac_source/4664375
#   inflating: hpac_source/9950411
#   inflating: hpac_source/6507698
#   inflating: hpac_source/7354569
#   inflating: hpac_source/12515830
#   inflating: hpac_source/10271960
#   inflating: hpac_source/7936072
#   inflating: hpac_source/7705553
#   inflating: hpac_source/7375880
#   inflating: hpac_source/10130315
#   inflating: hpac_source/6782910
#   inflating: hpac_source/6395367
#   inflating: hpac_source/8034383
#   inflating: hpac_source/10717034
#   inflating: hpac_source/11904271
#   inflating: hpac_source/3931314
#   inflating: hpac_source/2780738
# ...
#   inflating: hpac_source/7247482
#   inflating: hpac_source/9949146
#   inflating: hpac_source/4566621
#   inflating: hpac_source/5897196
#   inflating: hpac_source/9431314
#   inflating: hpac_source/9010059
#   inflating: hpac_source/12576316
#   inflating: hpac_source/2530375
#   inflating: hpac_source/1356797
#   inflating: hpac_source/11285236
#   inflating: hpac_source/617841
#   inflating: hpac_source/9814632
#   inflating: hpac_source/7439195
#   inflating: hpac_source/6020543
#   inflating: hpac_source/6329085
#   inflating: hpac_source/2814607
#   inflating: hpac_source/9940464
#   inflating: hpac_source/601118
#   inflating: hpac_source/2203519
#   inflating: hpac_source/2730217
#   inflating: hpac_source/4038148
#   inflating: hpac_source/5029957
#   inflating: hpac_source/7222688
#   inflating: hpac_source/3142433
#   inflating: hpac_source/5931444
#   inflating: hpac_source/5086821
#   inflating: hpac_source/7204178
#   inflating: hpac_source/11150374
#   inflating: hpac_source/11559461
#   inflating: hpac_source/9036306
#   inflating: hpac_source/10758913
#   inflating: hpac_source/10720809
#   inflating: hpac_source/8924070
#   inflating: hpac_source/5851615
#   inflating: hpac_source/10011793
#   inflating: hpac_source/4383247
#   inflating: hpac_source/11665240
#   inflating: hpac_source/7205298
#   inflating: hpac_source/3172094
#   inflating: hpac_source/5152540
#   inflating: hpac_source/4626929
#   inflating: hpac_source/6336851
#   inflating: hpac_source/6406619
#   inflating: hpac_source/2016734
#   inflating: hpac_source/7957090
#   inflating: hpac_source/7146786
#   inflating: hpac_source/3519301
#   inflating: hpac_source/4246668
#   inflating: hpac_source/7474966
#   inflating: hpac_source/5282170
#   inflating: hpac_source/11322299
#   inflating: hpac_source/2730025
#   inflating: hpac_source/4024725
#   inflating: hpac_source/2845297
#   inflating: hpac_source/1526914
#   inflating: hpac_source/3275890
#   inflating: hpac_source/5152918
#   inflating: hpac_source/11862130
#   inflating: hpac_source/8209523
#   inflating: hpac_source/2519406
#   inflating: hpac_source/3001084
#   inflating: hpac_source/3843667
#   inflating: hpac_source/1913465
#   inflating: hpac_source/2962157
#   inflating: hpac_source/2924742
#   inflating: hpac_source/7623794
#   inflating: hpac_source/12101417
#   inflating: hpac_source/12266992
#   inflating: hpac_source/7267872
#   inflating: hpac_source/8934686
#   inflating: hpac_source/10127713
#   inflating: hpac_source/7055673
#   inflating: hpac_source/12098185
#   inflating: hpac_source/11213800
#   inflating: hpac_source/12131282
#   inflating: hpac_source/9064745
#   inflating: hpac_source/4480047
#   inflating: hpac_source/11398259
#   inflating: hpac_source/11446957
#   inflating: hpac_source/7049822
#   inflating: hpac_source/11637431
#   inflating: hpac_source/7894922
#   inflating: hpac_source/11741537
#   inflating: hpac_source/12143490
#   inflating: hpac_source/2208595
#   inflating: hpac_source/4579602
#   inflating: hpac_source/5707073
#   inflating: hpac_source/7378120
#   inflating: hpac_source/3704725
#   inflating: hpac_source/6295006
#   inflating: hpac_source/2657435
#   inflating: hpac_source/4684916
#   inflating: hpac_source/11962284
#   inflating: hpac_source/9687649
#   inflating: hpac_source/6332861
#   inflating: hpac_source/4336009
#   inflating: hpac_source/4558111
#   inflating: hpac_source/6748088
#   inflating: hpac_source/9943443
#   inflating: hpac_source/3944530
#   inflating: hpac_source/4104634
#   inflating: hpac_source/5670261
#   inflating: hpac_source/7534992
#   inflating: hpac_source/4887058
#   inflating: hpac_source/9900724
#   inflating: hpac_source/7266954
#   inflating: hpac_source/4418575
#   inflating: hpac_source/2042848
#   inflating: hpac_source/3812031
#   inflating: hpac_source/7270831
#   inflating: hpac_source/6624626
#   inflating: hpac_source/3978568
#   inflating: hpac_source/10098585
#   inflating: hpac_source/5699502
#   inflating: hpac_source/10803290
#   inflating: hpac_source/5437259
#   inflating: hpac_source/7651172
#   inflating: hpac_source/4855774
#   inflating: hpac_source/11349136
#   inflating: hpac_source/9395466
#   inflating: hpac_source/2963243
#   inflating: hpac_source/4319674
#   inflating: hpac_source/3947187
#   inflating: hpac_source/11479742
#   inflating: hpac_source/2776092
#   inflating: hpac_source/6705047
#   inflating: hpac_source/4784058
#   inflating: hpac_source/11852563
#   inflating: hpac_source/3630462
#   inflating: hpac_source/2817412
#   inflating: hpac_source/1726075
#   inflating: hpac_source/10666104
#   inflating: hpac_source/9530971
#   inflating: hpac_source/9480367
#   inflating: hpac_source/4289865
#   inflating: hpac_source/12458958
#   inflating: hpac_source/4611763
#   inflating: hpac_source/2664889
#   inflating: hpac_source/3408301
#   inflating: hpac_source/1240921
#   inflating: hpac_source/2480736
#   inflating: hpac_source/6647710
#   inflating: hpac_source/5484126
#   inflating: hpac_source/12069887
#   inflating: hpac_source/8676626
#   inflating: hpac_source/7744370
#   inflating: hpac_source/2916210
#   inflating: hpac_source/10917140
#   inflating: hpac_source/9753784
#   inflating: hpac_source/4438516
#   inflating: hpac_source/7261729
#   inflating: hpac_source/10137111
#   inflating: hpac_source/3772107
#   inflating: hpac_source/4747050
#   inflating: hpac_source/4541458
#   inflating: hpac_source/12172575
#   inflating: hpac_source/6071127
#   inflating: hpac_source/8455955
#   inflating: hpac_source/3009679
#   inflating: hpac_source/9907959
#   inflating: hpac_source/7220319
#   inflating: hpac_source/1596270
#   inflating: hpac_source/6733373
#   inflating: hpac_source/12595514
#   inflating: hpac_source/7532261
#   inflating: hpac_source/3249038
#   inflating: hpac_source/8074678
#   inflating: hpac_source/9903199
#   inflating: hpac_source/3682293
#   inflating: hpac_source/1454026
#   inflating: hpac_source/6234214
#   inflating: hpac_source/12185542
#   inflating: hpac_source/12222020
#   inflating: hpac_source/2200506
#   inflating: hpac_source/4508659
#   inflating: hpac_source/6648136
#   inflating: hpac_source/2504147
#   inflating: hpac_source/3920871
#   inflating: hpac_source/7264435
#   inflating: hpac_source/4415060
#   inflating: hpac_source/10880326
#   inflating: hpac_source/4165409
#   inflating: hpac_source/6283993
#   inflating: hpac_source/7876259
#   inflating: hpac_source/9191701
#   inflating: hpac_source/5889897
#   inflating: hpac_source/11732835
#   inflating: hpac_source/3427312
#   inflating: hpac_source/12556524
#   inflating: hpac_source/4638487
#   inflating: hpac_source/2693082
#   inflating: hpac_source/7337446
#   inflating: hpac_source/11534401
#   inflating: hpac_source/12471280
#   inflating: hpac_source/11093460
#   inflating: hpac_source/4664962
#   inflating: hpac_source/3294338
#   inflating: hpac_source/7032329
#   inflating: hpac_source/8306277
#   inflating: hpac_source/12213131
#   inflating: hpac_source/1072718
#   inflating: hpac_source/3126986
#   inflating: hpac_source/10788198
#   inflating: hpac_source/5770589
#   inflating: hpac_source/12179397
#   inflating: hpac_source/5410215
#   inflating: hpac_source/10148818
#   inflating: hpac_source/3068444
#   inflating: hpac_source/9712982
#   inflating: hpac_source/2553244
#   inflating: hpac_source/12537177
#   inflating: hpac_source/7521020
#   inflating: hpac_source/7510555
#   inflating: hpac_source/2697274
#   inflating: hpac_source/5557666
#   inflating: hpac_source/2925238
#   inflating: hpac_source/7193071
#   inflating: hpac_source/12018014
#   inflating: hpac_source/11132738
#   inflating: hpac_source/6185277
#   inflating: hpac_source/7741408
#   inflating: hpac_source/6785310
#   inflating: hpac_source/8751388
#   inflating: hpac_source/7725971
#   inflating: hpac_source/6902901
#   inflating: hpac_source/7015739
#   inflating: hpac_source/2455207
#   inflating: hpac_source/10361251
#   inflating: hpac_source/10334295
#   inflating: hpac_source/8173379
#   inflating: hpac_source/10897701
#   inflating: hpac_source/7400487
#   inflating: hpac_source/2759849
#   inflating: hpac_source/5450703
#   inflating: hpac_source/8489713
#   inflating: hpac_source/7611804
#   inflating: hpac_source/3440442
#   inflating: hpac_source/2342097
#   inflating: hpac_source/10985342
#   inflating: hpac_source/2671799
#   inflating: hpac_source/9648286
#   inflating: hpac_source/12101279
#   inflating: hpac_source/7541131
#   inflating: hpac_source/12245542
#   inflating: hpac_source/3828504
#   inflating: hpac_source/12123915
#   inflating: hpac_source/4194537
#   inflating: hpac_source/12181572
#   inflating: hpac_source/3992026
#   inflating: hpac_source/8737952
#   inflating: hpac_source/9541572
#   inflating: hpac_source/7995724
#   inflating: hpac_source/1982640
#   inflating: hpac_source/7372274
#   inflating: hpac_source/8494890
#   inflating: hpac_source/7350124
#   inflating: hpac_source/7578629
#   inflating: hpac_source/6719282
#   inflating: hpac_source/11197380
#   inflating: hpac_source/9088934
#   inflating: hpac_source/11391788
#   inflating: hpac_source/8833945
#   inflating: hpac_source/2526687
#   inflating: hpac_source/2520928
#   inflating: hpac_source/9406757
#   inflating: hpac_source/9029580
#   inflating: hpac_source/9391238
#   inflating: hpac_source/2536071
#   inflating: hpac_source/6201107
#   inflating: hpac_source/5638522
#   inflating: hpac_source/1267999
#   inflating: hpac_source/12505617
#   inflating: hpac_source/3410564
#   inflating: hpac_source/12284813
#   inflating: hpac_source/9732915
#   inflating: hpac_source/3814138
#   inflating: hpac_source/4441344
#   inflating: hpac_source/1524011
#   inflating: hpac_source/8634807
#   inflating: hpac_source/7232046
#   inflating: hpac_source/7116698
#   inflating: hpac_source/2486069
#   inflating: hpac_source/11667379
#   inflating: hpac_source/7027865
#   inflating: hpac_source/8416494
#   inflating: hpac_source/9956961
#   inflating: hpac_source/11351105
#   inflating: hpac_source/9587008
#   inflating: hpac_source/7959764
#   inflating: hpac_source/6041128
#   inflating: hpac_source/2336324
#   inflating: hpac_source/10740123
#   inflating: hpac_source/3761517
#   inflating: hpac_source/4026081
#   inflating: hpac_source/3856510
#   inflating: hpac_source/2035545
#   inflating: hpac_source/7269543
#   inflating: hpac_source/11813702
#   inflating: hpac_source/7127742
#   inflating: hpac_source/4110465
#   inflating: hpac_source/1632190
#   inflating: hpac_source/5176514
#   inflating: hpac_source/7394594
#   inflating: hpac_source/12016383
#   inflating: hpac_source/6518656
#   inflating: hpac_source/1121754
#   inflating: hpac_source/1879799
#   inflating: hpac_source/12241915
#   inflating: hpac_source/12389219
#   inflating: hpac_source/5202688
#   inflating: hpac_source/12313088
#   inflating: hpac_source/4664161
#   inflating: hpac_source/7265980
#   inflating: hpac_source/10904762
#   inflating: hpac_source/9157076
#   inflating: hpac_source/7318452
#   inflating: hpac_source/4350812
#   inflating: hpac_source/7311389
#   inflating: hpac_source/7001762
#   inflating: hpac_source/6477219
#   inflating: hpac_source/3020790
#   inflating: hpac_source/9315964
#   inflating: hpac_source/4816414
#   inflating: hpac_source/8977720
#   inflating: hpac_source/5845682
#   inflating: hpac_source/5945704
#   inflating: hpac_source/8487226
#   inflating: hpac_source/10505826
#   inflating: hpac_source/4161096
#   inflating: hpac_source/5823490
#   inflating: hpac_source/6030346
#   inflating: hpac_source/3975042
#   inflating: hpac_source/7170441
#   inflating: hpac_source/9010253
#   inflating: hpac_source/3258949
#   inflating: hpac_source/7351459
#   inflating: hpac_source/6289698
#   inflating: hpac_source/7062230
#   inflating: hpac_source/6113270
#   inflating: hpac_source/12010622
#   inflating: hpac_source/11953702
#   inflating: hpac_source/12621002
#   inflating: hpac_source/12102261
#   inflating: hpac_source/6345934
#   inflating: hpac_source/2695178
#   inflating: hpac_source/9776292
#   inflating: hpac_source/1848688
#   inflating: hpac_source/11373890
#   inflating: hpac_source/8753084
#   inflating: hpac_source/10363961
#   inflating: hpac_source/5005504
#   inflating: hpac_source/5921073
#   inflating: hpac_source/7099096
#   inflating: hpac_source/10340119
#   inflating: hpac_source/12650061
#   inflating: hpac_source/2199592
#   inflating: hpac_source/9269590
#   inflating: hpac_source/3106112
#   inflating: hpac_source/11163707
#   inflating: hpac_source/9489817
#   inflating: hpac_source/12352028
#   inflating: hpac_source/2840988
#   inflating: hpac_source/8129568
#   inflating: hpac_source/4642201
#   inflating: hpac_source/3974958
#   inflating: hpac_source/11962283
#   inflating: hpac_source/6490414
#   inflating: hpac_source/12103175
#   inflating: hpac_source/7063316
#   inflating: hpac_source/10547069
#   inflating: hpac_source/12036126
#   inflating: hpac_source/1367820
#   inflating: hpac_source/10960485
#   inflating: hpac_source/9138779
#   inflating: hpac_source/10021565
#   inflating: hpac_source/9964292
#   inflating: hpac_source/3598389
#   inflating: hpac_source/9967417
#   inflating: hpac_source/3319605
#   inflating: hpac_source/10957035
#   inflating: hpac_source/12616446
#   inflating: hpac_source/3762702
#   inflating: hpac_source/7026386
#   inflating: hpac_source/7352228
#   inflating: hpac_source/7798151
#   inflating: hpac_source/11499963
#   inflating: hpac_source/7216688
#   inflating: hpac_source/9484162
#   inflating: hpac_source/1970766
#   inflating: hpac_source/3792528
#   inflating: hpac_source/5454992
#   inflating: hpac_source/5293237
#   inflating: hpac_source/8479350
#   inflating: hpac_source/4187923
#   inflating: hpac_source/7023290
#   inflating: hpac_source/8156001
#   inflating: hpac_source/6492515
#   inflating: hpac_source/7358376
#   inflating: hpac_source/4625797
#   inflating: hpac_source/2798371
#   inflating: hpac_source/6183977
#   inflating: hpac_source/9907196
#   inflating: hpac_source/7712536
#   inflating: hpac_source/9642783
#   inflating: hpac_source/2837482
#   inflating: hpac_source/2989732
#   inflating: hpac_source/4900067
#   inflating: hpac_source/10258404
#   inflating: hpac_source/4058896
#   inflating: hpac_source/12458197
#   inflating: hpac_source/7529286
#   inflating: hpac_source/6945403
#   inflating: hpac_source/12724254
#   inflating: hpac_source/8983962
#   inflating: hpac_source/5733625
#   inflating: hpac_source/3909168
#   inflating: hpac_source/8895981
#   inflating: hpac_source/5804622
#   inflating: hpac_source/8903467
#   inflating: hpac_source/3811011
#   inflating: hpac_source/3909954

# %%
# !ls hpac_source | wc -l
# Out:
#    36225

# %%
# !unzip hpac_splits
# Out:
# Archive:  hpac_splits.zip
#    creating: hpac_corpus/
#   inflating: hpac_corpus/hpac_training_128.tsv
#    creating: __MACOSX/
#    creating: __MACOSX/hpac_corpus/
#   inflating: __MACOSX/hpac_corpus/._hpac_training_128.tsv
#   inflating: hpac_corpus/hpac_dev_128.tsv
#   inflating: __MACOSX/hpac_corpus/._hpac_dev_128.tsv
#   inflating: hpac_corpus/hpac_test_128.tsv
#   inflating: __MACOSX/hpac_corpus/._hpac_test_128.tsv
#   inflating: __MACOSX/._hpac_corpus

# %% [markdown]
# train, test, dev файлы

# %%
import pandas as pd
df = pd.read_csv('hpac_corpus/hpac_training_128.tsv', sep = '\t', header = None)

# %%
df.columns = ['first', 'target', 'text']

# %%
df.head()
# Out:
#              first        target  \
# 0    7642954.0.676    RIDDIKULUS
# 1  10443333.0.5753    RIDDIKULUS
# 2   4703706.0.8690       STUPEFY
# 3   4593427.0.1815         ACCIO
# 4   4278446.0.2692  EXPELLIARMUS
#
#                                                 text
# 0  were staring at her . she was up next to face ...
# 1  that whole time . her first reaction , for whi...
# 2  we watched his inglorious withdrawal together ...
# 3  my wand , `` incendio . '' this wretched chill...
# 4  already compared ours , they 're the same ever...

# %%
df.iloc[0][1], df.iloc[0][2]
# Out:
# ('RIDDIKULUS',
#  "were staring at her . she was up next to face the boggart in defense against the dark arts class . she was not scared , but what she was worried about was what had happened with lysander . she looked up at the boggart in front of her which had previously been a humongous spider . its eyes locked on her . before she could think of what frightened her , the spider transformed into lysander . he was dying . there were giggles coming from the male and female hufflepuff students . there was a smirk on lorcan 's face . `` lily help me '' i ca n't fail this class because of a secret love . lily lifted her wand and said , ``")

# %% [markdown]
# ### Как использовать WordNet из nltk?

# %%
# скачиваем WordNet
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /Users/alex/nltk_data...
# True

# %%
# слово -> множество синсетов (синонимов разных смыслов исходного слова)
from nltk.corpus import wordnet as wn
wn.synsets('magic')
# Out:
# [Synset('magic.n.01'), Synset('magic_trick.n.01'), Synset('charming.s.02')]

# %%
# посмотрим, что внутри одного синсета
wn.synsets('magic')[1].lemmas()[0]
# Out:
# Lemma('magic_trick.n.01.magic_trick')

# %%
# возьмем лемму одного из слов из синсета
wn.synsets('magic')[1].lemmas()[-1].name()
# Out:
# 'deception'

# %%
from nltk.corpus import stopwords
from nltk.tokenize import wordpunct_tokenize
from nltk.probability import FreqDist

# %%
stop_words = set(stopwords.words('english'))

# %%
all_words = ' '.join(df.text)

# %%
fd = FreqDist(
    word
    for word in wordpunct_tokenize(all_words)
    if word not in set(stopwords.words('french'))
)
fd.pprint()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/81/4_33342131b1t4_6vpnzvynm0000gn/T/ipykernel_75352/1673826696.py in <module>
# ----> 1 fd = FreqDist(
#       2     word
#       3     for word in wordpunct_tokenize(all_words)
#       4     if word not in set(stopwords.words('french'))
#       5 )
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/nltk/probability.py in __init__(self, samples)
#     100         :type samples: Sequence
#     101         """
# --> 102         Counter.__init__(self, samples)
#     103
#     104         # Cached number of samples in this FreqDist
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/collections/__init__.py in __init__(self, iterable, **kwds)
#     591         '''
#     592         super().__init__()
# --> 593         self.update(iterable, **kwds)
#     594
#     595     def __missing__(self, key):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/nltk/probability.py in update(self, *args, **kwargs)
#     138         """
#     139         self._N = None
# --> 140         super().update(*args, **kwargs)
#     141
#     142     def setdefault(self, key, val):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/collections/__init__.py in update(self, iterable, **kwds)
#     677                     super().update(iterable)
#     678             else:
# --> 679                 _count_elements(self, iterable)
#     680         if kwds:
#     681             self.update(kwds)
#
# /var/folders/81/4_33342131b1t4_6vpnzvynm0000gn/T/ipykernel_75352/1673826696.py in <genexpr>(.0)
#       2     word
#       3     for word in wordpunct_tokenize(all_words)
# ----> 4     if word not in set(stopwords.words('french'))
#       5 )
#       6 fd.pprint()
#
# KeyboardInterrupt:
